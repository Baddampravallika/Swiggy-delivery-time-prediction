# %% [markdown]
# ## Business Problem
# Swiggy processes millions of food-delivery journeys across hundreds of cities every month. Accurate Estimated Time of Arrival (ETA) at order placement and during delivery is core to the customer experience — it affects conversion, cancellations, ratings, and retention. Today’s ETA accuracy suffers from many sources of uncertainty: highly variable traffic patterns, weather events, restaurant preparation variability, rider behaviour and skill, order batching/multiple deliveries, and city-specific operational constraints. Inaccurate ETAs cause:
# * Reduced customer trust and lower repeat orders.
# * Increased cancellations and refund costs.
# * Higher support volume and operational interventions.
# * Sub-optimal rider allocation and increased rider idle or overtime costs.
#
# ## Problem Statement
# Swiggy’s objective is to predict the delivery time (minutes) per order at the moment of order placement (and update it dynamically), with business-grade accuracy and uncertainty estimates so the platform can
#  (a) show reliable ETAs to customers
#  (b) optimize rider allocation.
# Build a production-ready, scalable Machine Learning system that predicts per-order delivery time (in minutes) using real-time and historical features (order, rider, restaurant, geospatial, traffic, weather, and temporal signals).

# %% [markdown]
# ## Dataset Overview
# * Rider_id:- Unique identifier for each delivery partner.
# * Age       :- Age of the delivery partner.
# * Ratings                :-  Average customer rating of the rider.
# * vehicle_condition:-Condition of the rider’s vehicle.(0 => poor ,1=>Average, 2=>Good)
# * Type_of_vehicle   :-Vehicle used for delivery (motorcycle, scooter, etc.).
# * Type_of_order      :-Type of food ordered (snack, meal, drinks, buffet).
# * multiple_deliveries:-Number of deliveries assigned to the rider in a single trip.
# * pickup_time_minutes:-Time taken by the restaurant to prepare the order.
# * restaurant_longitude:-Geographic coordinates of the restaurant.
# * delivery_longitude:- Geographic coordinates of the customer’s delivery location.
# * Is_weekend             :-Indicates whether the order was placed on a weekend.
# * Order_time_hour    :-Hour when the order was placed (0–23).
# * order_time_of_day:- Time bucket (morning, afternoon, evening, night).
# * Weather                   :-Weather condition during delivery (sunny, cloudy, fog, stormy, sandstorms).
# * Traffic                      :-Traffic condition during delivery.
# * Festival                    :-Indicates whether the order was placed on a festival day.
# * City_type                 :-Classification of city (urban, metropolitan).
# * City_name               :-Name/code of the city (BANG, HYD, CHEN, etc.).
# * Time_taken              :- Actual time taken (in minutes) to complete the delivery.
# * Distance                   :-Distance (in km) between restaurant and delivery location.
# * Order_date               :-Date when the order was placed.
# * Order_day                :-Day of the month.
# * Order_month           :-Month of the order.
# * order_day_of_week:-Day of the week (Monday–Sunday).

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\PRAVALLIKA\Downloads\swiggy_demographic.csv")
df
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45497     JAPRES04DEL01   30.0      4.8            26.902328
# 45498     AGRRES16DEL01   21.0      4.6                  NaN
# 45499    CHENRES08DEL03   30.0      4.9            13.022394
# 45500   COIMBRES11DEL01   20.0      4.7            11.001753
# 45501  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 0                 75.892471          22.765049           75.912471
# 1                 77.683237          13.043041           77.813237
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['rider_id', 'age', 'ratings', 'restaurant_latitude',
#        'restaurant_longitude', 'delivery_latitude', 'delivery_longitude',
#        'order_date', 'weather', 'traffic', 'vehicle_condition',
#        'type_of_order', 'type_of_vehicle', 'multiple_deliveries', 'festival',
#        'city_type', 'time_taken', 'city_name', 'order_day', 'order_month',
#        'order_day_of_week', 'is_weekend', 'pickup_time_minutes',
#        'order_time_hour', 'order_time_of_day', 'distance'],
#       dtype='str')

# %%
numerical=['age','ratings','vehicle_condition','multiple_deliveries','order_day','order_month','is_weekend',
           'pickup_time_minutes','order_time_hour','distance']

# %% [markdown]
# # Dropping irrelevant columns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.columns
# Out:
# Index(['rider_id', 'age', 'ratings', 'restaurant_latitude',
#        'restaurant_longitude', 'delivery_latitude', 'delivery_longitude',
#        'order_date', 'weather', 'traffic', 'vehicle_condition',
#        'type_of_order', 'type_of_vehicle', 'multiple_deliveries', 'festival',
#        'city_type', 'time_taken', 'city_name', 'order_day', 'order_month',
#        'order_day_of_week', 'is_weekend', 'pickup_time_minutes',
#        'order_time_hour', 'order_time_of_day', 'distance'],
#       dtype='str')

# %%
df = df.drop(columns=['rider_id', 'order_date', 'restaurant_latitude', 'restaurant_longitude', 'delivery_latitude', 'delivery_longitude'])

# %%
x=df.drop(columns=['time_taken'])
y=df['time_taken']

# %%
x.head(5)
# Out:
#     age  ratings     weather traffic  vehicle_condition type_of_order  \
# 0  37.0      4.9       sunny    high                  2         snack
# 1  34.0      4.5      stormy     jam                  2         snack
# 2  23.0      4.4  sandstorms     low                  0        drinks
# 3  38.0      4.7       sunny  medium                  0        buffet
# 4  32.0      4.6      cloudy    high                  1         snack
#
#   type_of_vehicle  multiple_deliveries festival      city_type city_name  \
# 0      motorcycle                  0.0       no          urban      INDO
# 1         scooter                  1.0       no  metropolitian      BANG
# 2      motorcycle                  1.0       no          urban      BANG
# 3      motorcycle                  1.0       no  metropolitian     COIMB
# 4         scooter                  1.0       no  metropolitian      CHEN
#
#    order_day  order_month order_day_of_week  is_weekend  pickup_time_minutes  \
# ...

# %%
x.columns
# Out:
# Index(['age', 'ratings', 'weather', 'traffic', 'vehicle_condition',
#        'type_of_order', 'type_of_vehicle', 'multiple_deliveries', 'festival',
#        'city_type', 'city_name', 'order_day', 'order_month',
#        'order_day_of_week', 'is_weekend', 'pickup_time_minutes',
#        'order_time_hour', 'order_time_of_day', 'distance'],
#       dtype='str')

# %%
df.describe().T
# Out:
#                        count       mean       std        min        25%  \
# age                  43648.0  29.555008  5.761482  20.000000  25.000000
# ratings              43594.0   4.635287  0.313827   2.500000   4.500000
# vehicle_condition    45502.0   1.019406  0.835229   0.000000   0.000000
# multiple_deliveries  44509.0   0.744928  0.572488   0.000000   0.000000
# time_taken           45502.0  26.297591  9.386419  10.000000  19.000000
# order_day            45502.0  13.811657  8.709540   1.000000   6.000000
# order_month          45502.0   2.980726  0.546031   2.000000   3.000000
# is_weekend           45502.0   0.274867  0.446452   0.000000   0.000000
# pickup_time_minutes  43862.0   9.989399  4.087516   5.000000   5.000000
# order_time_hour      43862.0  17.423966  4.817856   0.000000  15.000000
# distance             41872.0   9.719296  5.602890   1.465067   4.657655
#
#                            50%       75%        max
# ...

# %%
df.head()
# Out:
#     age  ratings     weather traffic  vehicle_condition type_of_order  \
# 0  37.0      4.9       sunny    high                  2         snack
# 1  34.0      4.5      stormy     jam                  2         snack
# 2  23.0      4.4  sandstorms     low                  0        drinks
# 3  38.0      4.7       sunny  medium                  0        buffet
# 4  32.0      4.6      cloudy    high                  1         snack
#
#   type_of_vehicle  multiple_deliveries festival      city_type  time_taken  \
# 0      motorcycle                  0.0       no          urban          24
# 1         scooter                  1.0       no  metropolitian          33
# 2      motorcycle                  1.0       no          urban          26
# 3      motorcycle                  1.0       no  metropolitian          21
# 4         scooter                  1.0       no  metropolitian          30
#
#   city_name  order_day  order_month order_day_of_week  is_weekend  \
# ...

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# ## 1)Handling missing values

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45502 entries, 0 to 45501
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  43648 non-null  float64
#  1   ratings              43594 non-null  float64
#  2   weather              44977 non-null  str
#  3   traffic              44992 non-null  str
#  4   vehicle_condition    45502 non-null  int64
#  5   type_of_order        45502 non-null  str
#  6   type_of_vehicle      45502 non-null  str
#  7   multiple_deliveries  44509 non-null  float64
#  8   festival             45274 non-null  str
#  9   city_type            44304 non-null  str
#  10  time_taken           45502 non-null  int64
#  11  city_name            45502 non-null  str
#  12  order_day            45502 non-null  int64
#  13  order_month          45502 non-null  int64
#  14  order_day_of_week    45502 non-null  str
#  15  is_weekend           45502 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# age                    1854
# ratings                1908
# weather                 525
# traffic                 510
# vehicle_condition         0
# type_of_order             0
# type_of_vehicle           0
# multiple_deliveries     993
# festival                228
# city_type              1198
# time_taken                0
# city_name                 0
# order_day                 0
# order_month               0
# order_day_of_week         0
# is_weekend                0
# pickup_time_minutes    1640
# order_time_hour        1640
# order_time_of_day         0
# distance               3630
# dtype: int64

# %% [markdown]
# # Segregating the columns based on datatype

# %%
df["weather"].head()
# Out:
# 0         sunny
# 1        stormy
# 2    sandstorms
# 3         sunny
# 4        cloudy
# Name: weather, dtype: str

# %%
# nominal
nominal=['weather','type_of_order','type_of_vehicle','festival','city_name','order_day_of_week','order_time_of_day']
nominal
# Out:
# ['weather',
#  'type_of_order',
#  'type_of_vehicle',
#  'festival',
#  'city_name',
#  'order_day_of_week',
#  'order_time_of_day']

# %%
# ordinal
ordinal=['traffic','city_type']
ordinal
# Out:
# ['traffic', 'city_type']

# %%
df['city_type'].unique()
# Out:
# <StringArray>
# ['urban', 'metropolitian', 'semi-urban', nan]
# Length: 4, dtype: str

# %%
order=[["low","medium","high","jam"],['semi-urban','urban','metropolitian']]

# %%
# numerical
numerical=['age','ratings','vehicle_condition','multiple_deliveries','order_day','order_month','is_weekend',
           'pickup_time_minutes','order_time_hour','distance']
numerical
# Out:
# ['age',
#  'ratings',
#  'vehicle_condition',
#  'multiple_deliveries',
#  'order_day',
#  'order_month',
#  'is_weekend',
#  'pickup_time_minutes',
#  'order_time_hour',
#  'distance']

# %% [markdown]
# # Pipeline Creation

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.compose import ColumnTransformer

# %%
numerical_pipeline=Pipeline([("Numerical impution",SimpleImputer(strategy="median")),
                            ("Feature Scaling",StandardScaler())])
numerical_pipeline
# Out:
# Pipeline(steps=[('Numerical impution', SimpleImputer(strategy='median')),
#                 ('Feature Scaling', StandardScaler())])

# %%
nominal_pipeline=Pipeline([("nominal imputation",SimpleImputer(strategy="most_frequent")),
                          ("Encoding",OneHotEncoder())])
nominal_pipeline
# Out:
# Pipeline(steps=[('nominal imputation', SimpleImputer(strategy='most_frequent')),
#                 ('Encoding', OneHotEncoder())])

# %%
ordinal_pipeline=Pipeline([("Ordinal imputation",SimpleImputer(strategy="most_frequent")),
                          ("Encoding",OrdinalEncoder(categories=order))])
ordinal_pipeline
# Out:
# Pipeline(steps=[('Ordinal imputation', SimpleImputer(strategy='most_frequent')),
#                 ('Encoding',
#                  OrdinalEncoder(categories=[['low', 'medium', 'high', 'jam'],
#                                             ['semi-urban', 'urban',
#                                              'metropolitian']]))])

# %%
Data_preprocessing = ColumnTransformer([
    ('Nominal transformation', nominal_pipeline, nominal),
    ("Ordinal transformation", ordinal_pipeline, ordinal),
    ('Numerical Transformation', numerical_pipeline, numerical)
])

Data_preprocessing
# Out:
# ColumnTransformer(transformers=[('Nominal transformation',
#                                  Pipeline(steps=[('nominal imputation',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('Encoding',
#                                                   OneHotEncoder())]),
#                                  ['weather', 'type_of_order', 'type_of_vehicle',
#                                   'festival', 'city_name', 'order_day_of_week',
#                                   'order_time_of_day']),
#                                 ('Ordinal transformation',
#                                  Pipeline(steps=[('Ordinal imputation',
#                                                   SimpleImpute...
#                                                                              ['semi-urban',
#                                                                               'urban',
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=23)

# %% [markdown]
# # Model Building

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,root_mean_squared_error,r2_score

# %%
lr = Pipeline([
    ('Data Preprocessing', Data_preprocessing),
    ("Algorithm", LinearRegression())
])

lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("root_mean_squared_error",root_mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# mean_squared_error 36.94136258193891
# root_mean_squared_error 6.07794065304515
# R2 score 0.5845096813390458

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_r=Pipeline([
    ("Data Preprocessing",Data_preprocessing),
    ("Algorithm",KNeighborsRegressor())
])

knn_r.fit(x_train,y_train)
y_pred = knn_r.predict(x_test)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("root_mean_squared_error",root_mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# mean_squared_error 34.29343588616636
# root_mean_squared_error 5.85605975773526
# R2 score 0.6142916880037183

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=Pipeline([
    ("Data Preprocessing",Data_preprocessing),
    ("Algorithm",DecisionTreeRegressor())
])

dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("root_mean_squared_error",root_mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# mean_squared_error 31.537303593011757
# root_mean_squared_error 5.6158083650541135
# R2 score 0.6452907146967517

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVR

# %%
svr = Pipeline([
    ('Data Preprocessing', Data_preprocessing),
    ("Algorithm",SVR())
])

svr.fit(x_train,y_train)
y_pred = svr.predict(x_test)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("root_mean_squared_error",root_mean_squared_error(y_test,y_pred))
print("R2_score",r2_score(y_test,y_pred))
# Out:
# mean_squared_error 25.880548012840787
# root_mean_squared_error 5.087292798025369
# R2_score 0.7089139005870705

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RandomForestRegressor()
# Out:
# RandomForestRegressor()

# %%
rf = Pipeline([
    ('Data Preprocessing', Data_preprocessing),
    ("Algorithm", RandomForestRegressor(random_state=23))
])

rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("root_mean_squared_error",root_mean_squared_error(y_test,y_pred))
print("r2_score",r2_score(y_test,y_pred))
# Out:
# mean_squared_error 16.9511627293704
# root_mean_squared_error 4.117178977087394
# r2_score 0.8093453107346065

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

rf.fit(x_train, y_train)


train_pred = rf.predict(x_train)
y_pred = rf.predict(x_test)


train_r2 = r2_score(y_train, train_pred)
test_r2 = r2_score(y_test, y_pred)

print(f"Training R2 Score: {train_r2:.4f}")
print(f"Test R2 Score: {test_r2:.4f}")
# Out:
# Training R2 Score: 0.9728
# Test R2 Score: 0.8093

# %% [markdown]
# # XGBoost

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBRegressor

# %%
xgb = Pipeline([
    ('Data Preprocessing', Data_preprocessing),
    ("Algorithm", XGBRegressor())
])

xgb.fit(x_train,y_train)
y_pred = xgb.predict(x_test)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("root_mean_squared_error",root_mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# mean_squared_error 16.646299362182617
# root_mean_squared_error 4.079987525939941
# R2 score 0.8127741813659668

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

xgb.fit(x_train, y_train)


train_pred = xgb.predict(x_train)
y_pred = xgb.predict(x_test)

train_r2 = r2_score(y_train, train_pred)
test_r2 = r2_score(y_test, y_pred)

print(f"Training R2 Score: {train_r2:.4f}")
print(f"Test R2 Score: {test_r2:.4f}")
# Out:
# Training R2 Score: 0.8634
# Test R2 Score: 0.8128

# %% [markdown]
# # kfold-Cross validation

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
kfcv=KFold(n_splits=5,shuffle=True,random_state=23)

# %%
cross_val_score(estimator=xgb,
               X=x,
               y=y,
               scoring='r2',
               cv=kfcv,
               n_jobs=-1).mean()
# Out:
# np.float64(0.8084364891052246)

# %% [markdown]
# # Hyperparamaters

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'Algorithm__n_estimators': [100, 200, 300],
    'Algorithm__max_depth': [4, 6, 7, 8],
    'Algorithm__learning_rate': [0.05, 0.1, 0.01],
    }

grid_xgb = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid,
    cv=kfcv,
    scoring='r2',
    n_jobs=-1
)

grid_xgb.fit(x_train, y_train)

print("Best Parameters:", grid_xgb.best_params_)
print("Best CV Score:", grid_xgb.best_score_)
# Out:
# Best Parameters: {'Algorithm__learning_rate': 0.05, 'Algorithm__max_depth': 8, 'Algorithm__n_estimators': 200}
# Best CV Score: 0.8157662153244019

# %% [markdown]
# # Bayesian Optimization

# %%
def Objective(trial):
    # creating  search space
    n_estimators=trial.suggest_int("n_estimators",100,150,200)
    learning_rate=trial.suggest_float("learning_rate",0.01,0.1)
    Algorithm__max_depth=trial.suggest_int("Algorithm__max_depth",6,8)
    Algorithm__subsample=trial.suggest_float("Algorithm__subsample",0.8,1.0)
    
    # Training
    xgb=XGBRegressor(n_estimators=n_estimators,learning_rate=learning_rate,max_depth=Algorithm__max_depth,subsample=Algorithm__subsample)

    trial_pipeline = Pipeline(steps=[
        ('Data Preprocessing', Data_preprocessing), 
        ('Algorithm', xgb)])
    
    #scoring
    score=cross_val_score(trial_pipeline,x,y,scoring="r2",cv=kfcv,n_jobs=-1).mean()
    return score

# %%
import optuna

# %%
study=optuna.create_study(direction="maximize")
# Out:
# [I 2026-06-03 22:42:05,822] A new study created in memory with name: no-name-0693734f-57e3-4bb8-843d-fea67529ac2d

# %%
study.optimize(Objective,n_trials=10)
# Out:
# [I 2026-06-03 22:42:13,368] Trial 0 finished with value: 0.818324065208435 and parameters: {'n_estimators': 100, 'learning_rate': 0.08657899429720124, 'Algorithm__max_depth': 8, 'Algorithm__subsample': 0.8697359859901279}. Best is trial 0 with value: 0.818324065208435.
# [I 2026-06-03 22:42:20,482] Trial 1 finished with value: 0.8146021723747253 and parameters: {'n_estimators': 100, 'learning_rate': 0.05325801060485064, 'Algorithm__max_depth': 7, 'Algorithm__subsample': 0.8698508478328404}. Best is trial 0 with value: 0.818324065208435.
# [I 2026-06-03 22:42:26,744] Trial 2 finished with value: 0.8175082683563233 and parameters: {'n_estimators': 100, 'learning_rate': 0.04739683089409798, 'Algorithm__max_depth': 8, 'Algorithm__subsample': 0.888474437324614}. Best is trial 0 with value: 0.818324065208435.
# ...

# %%
study.best_params
# Out:
# {'n_estimators': 100,
#  'learning_rate': 0.05868330405604828,
#  'Algorithm__max_depth': 8,
#  'Algorithm__subsample': 0.8045836370772147}

# %% [markdown]
# # Final model

# %%
from sklearn.metrics import r2_score

# %%
# tuned hyperparameters from bayesian optimization 
xgb_model = Pipeline([('Data Preprocessing', Data_preprocessing),
                     ("Algorithm", XGBRegressor(
                         n_estimators=200,
                          learning_rate=0.05,
                          max_depth=8,
                           random_state=23))])


xgb_model.fit(x_train, y_train)
y_pred = xgb_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2score = r2_score(y_test,y_pred)
print("XGBoost")
print("Mean_Squared_Error:", mse)
print("Root_Mean_Squared_Error:", rmse)
print("R2_Score:",r2score)
# Out:
# XGBoost
# Mean_Squared_Error: 15.893646240234375
# Root_Mean_Squared_Error: 3.9866836071014404
# R2_Score: 0.8212394714355469

# %%
final_pipeline = xgb_model.fit(x, y)
final_pipeline
# Out:
# Pipeline(steps=[('Data Preprocessing',
#                  ColumnTransformer(transformers=[('Nominal transformation',
#                                                   Pipeline(steps=[('nominal '
#                                                                    'imputation',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('Encoding',
#                                                                    OneHotEncoder())]),
#                                                   ['weather', 'type_of_order',
#                                                    'type_of_vehicle',
#                                                    'festival', 'city_name',
#                                                    'order_day_of_week',
#                                                    'order_time_of_day']),
# ...

# %%
import pickle

# %%
with open(r"C:\Users\PRAVALLIKA\Downloads.pkl", "wb") as s:
    pickle.dump(final_pipeline, s)

# %%
with open(r"C:\Users\PRAVALLIKA\Downloads.pkl", 'rb') as swiggyproject:
    model = pickle.load(swiggyproject)

# %%
import pandas as pd

swiggy_delivery = pd.DataFrame([{'age':25,'ratings': 5,'weather': 'cloudy','traffic': 'jam','vehicle_condition': 1,'type_of_order': 'meal',
                      'type_of_vehicle': 'motorcycle','multiple_deliveries': 3,'festival': 'no','city_type': 'urban','city_name': 'BANG',
                      'order_day': 13,'order_month': 6,'order_day_of_week': 'saturday','is_weekend': 1,'pickup_time_minutes': 10,
                      'order_time_hour': 18,'order_time_of_day': 'evening','distance': 5.5}])
y_pred = final_pipeline.predict(swiggy_delivery)

print("Delivery Time:", y_pred[0])
# Out:
# Delivery Time: 41.263344
